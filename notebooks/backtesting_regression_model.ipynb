# %% [markdown]
# # Backtesting ML Regression-Based

# %% [markdown]
# ## Load the model

# %%
import pickle

# %%
with open('models/model_dt_regression.pkl', 'rb') as f:
    model_dt = pickle.load(f)

# %%
model_dt
# Out:
# DecisionTreeRegressor(max_depth=15)

# %% [markdown]
# ## Load the data

# %%
import pandas as pd

df = pd.read_excel('data/Microsoft_LinkedIn_Processed.xlsx', index_col=0, parse_dates=['Date'])
df
# Out:
#                  Close        High         Low        Open    Volume  \
# Date
# 2016-12-08   55.181129   55.696675   55.027373   55.443424  21220800
# 2016-12-09   56.049412   56.067501   55.289665   55.334887  27349400
# 2016-12-12   56.230301   56.347882   55.823296   55.913741  20198100
# 2016-12-13   56.962925   57.360886   56.293626   56.528784  35718900
# 2016-12-14   56.691582   57.388017   56.555911   56.981009  30352700
# ...                ...         ...         ...         ...       ...
# 2025-02-27  392.529999  405.739990  392.170013  401.269989  21127400
# 2025-02-28  396.989990  397.630005  386.570007  392.660004  32845700
# 2025-03-03  388.489990  398.820007  386.160004  398.820007  23007700
# 2025-03-04  388.609985  392.579987  381.000000  383.399994  29342900
# 2025-03-05  401.019989  401.670013  388.809998  389.339996  23412000
#
#             change_tomorrow change_tomorrow_direction
# Date
# 2016-12-08         1.549137                        UP
# 2016-12-09         0.321693                        UP
# 2016-12-12         1.286142                        UP
# 2016-12-13        -0.478631                      DOWN
# 2016-12-14        -0.159803                      DOWN
# ...                     ...                       ...
# 2025-02-27         1.123452                        UP
# 2025-02-28        -2.187959                      DOWN
# 2025-03-03         0.030878                        UP
# 2025-03-04         3.094610                        UP
# 2025-03-05              NaN                      DOWN
#
# [2070 rows x 7 columns]

# %% [markdown]
# ## Backtesting.py Library

# %% [markdown]
# ### Create your Strategy Class

# %%
from backtesting import Backtest, Strategy
# Out:
# /home/codespace/.python/current/lib/python3.12/site-packages/backtesting/_plotting.py:54: UserWarning: Jupyter Notebook detected. Setting Bokeh output to notebook. This may not work in Jupyter clients without JavaScript support (e.g. PyCharm, Spyder IDE). Reset with `backtesting.set_bokeh_output(notebook=False)`.
#   warnings.warn('Jupyter Notebook detected. '
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="c03c31b5-4aff-4f84-9c1c-bbc55206831d">Loading BokehJS ...</span>
#     </div>

# %%
class Regression(Strategy):
    def init(self):
        self.model = model_dt
        self.already_bought = False

    def next(self):
        explanatory_today = self.data.df.iloc[[-1], :]
        forecast_tomorrow = self.model.predict(explanatory_today)[0]
        
        if forecast_tomorrow > 1 and self.already_bought == False:
            self.buy()
            self.already_bought = True
        elif forecast_tomorrow < -5 and self.already_bought == True:
            self.sell()
            self.already_bought = False
        else:
            pass

# %% [markdown]
# ### Define initial conditions

# %%
df_explanatory = df[['Open', 'High', 'Low', 'Close', 'Volume']].copy()

# %%
df_explanatory.iloc[-1:, :]
# Out:
#                   Open        High         Low       Close    Volume
# Date
# 2025-03-05  389.339996  401.670013  388.809998  401.019989  23412000

# %%
bt = Backtest(df_explanatory, Regression,
              cash=10000, commission=.002, exclusive_orders=True)

# %% [markdown]
# ### Run backtesting

# %%
results = bt.run()

# %% [markdown]
# ### Interpret backtesting results

# %%
results.to_frame(name='Values').loc[:'Return [%]']
# Out:
#                                 Values
# Start              2016-12-08 00:00:00
# End                2025-03-05 00:00:00
# Duration            3009 days 00:00:00
# Exposure Time [%]            92.753623
# Equity Final [$]           75469.03052
# Equity Peak [$]           89289.821532
# Commissions [$]            2679.450454
# Return [%]                  654.690305

# %% [markdown]
# ### Visualize the strategy performance

# %%
bt.plot(filename='reports_backtesting/backtesting_regression.html')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 bt.plot(filename='reports_backtesting/backtesting_regression.html')
#
# File ~/.python/current/lib/python3.12/site-packages/backtesting/backtesting.py:1752, in Backtest.plot(self, results, filename, plot_width, plot_equity, plot_return, plot_pl, plot_volume, plot_drawdown, plot_trades, smooth_equity, relative_equity, superimpose, resample, reverse_indicators, show_legend, open_browser)
#    1749         raise RuntimeError('First issue `backtest.run()` to obtain results.')
#    1750     results = self._results
# -> 1752 return plot(
#    1753     results=results,
#    1754     df=self._data,
#    1755     indicators=results._strategy._indicators,
#    1756     filename=filename,
#    1757     plot_width=plot_width,
#    1758     plot_equity=plot_equity,
#    1759     plot_return=plot_return,
#    1760     plot_pl=plot_pl,
#    1761     plot_volume=plot_volume,
#    1762     plot_drawdown=plot_drawdown,
#    1763     plot_trades=plot_trades,
#    1764     smooth_equity=smooth_equity,
#    1765     relative_equity=relative_equity,
#    1766     superimpose=superimpose,
#    1767     resample=resample,
#    1768     reverse_indicators=reverse_indicators,
#    1769     show_legend=show_legend,
#    1770     open_browser=open_browser)
#
# File ~/.python/current/lib/python3.12/site-packages/backtesting/_plotting.py:712, in plot(results, df, indicators, filename, plot_width, plot_equity, plot_return, plot_pl, plot_volume, plot_drawdown, plot_trades, smooth_equity, relative_equity, superimpose, resample, reverse_indicators, show_legend, open_browser)
#     702     kwargs['sizing_mode'] = 'stretch_width'
#     704 fig = gridplot(
#     705     figs,
#     706     ncols=1,
#    (...)
#     710     **kwargs  # type: ignore
#     711 )
# --> 712 show(fig, browser=None if open_browser else 'none')
#     713 return fig
#
# File ~/.python/current/lib/python3.12/site-packages/bokeh/io/showing.py:147, in show(obj, browser, new, notebook_handle, notebook_url, **kwargs)
#     144 state = curstate()
#     146 if isinstance(obj, UIElement):
# --> 147     return _show_with_state(obj, state, browser, new, notebook_handle=notebook_handle)
#     149 def is_application(obj: Any) -> TypeGuard[Application]:
#     150     return getattr(obj, '_is_a_bokeh_application_class', False)
#
# File ~/.python/current/lib/python3.12/site-packages/bokeh/io/showing.py:198, in _show_with_state(obj, state, browser, new, notebook_handle)
#     195     shown = True
#     197 if state.file or not shown:
# --> 198     _show_file_with_state(obj, state, new, controller)
#     200 return comms_handle
#
# File ~/.python/current/lib/python3.12/site-packages/bokeh/io/showing.py:179, in _show_file_with_state(obj, state, new, controller)
#     175 def _show_file_with_state(obj: UIElement, state: State, new: BrowserTarget, controller: BrowserLike) -> None:
#     176     '''
#     177
#     178     '''
# --> 179     filename = save(obj, state=state)
#     180     controller.open("file://" + filename, new=NEW_PARAM[new])
#
# File ~/.python/current/lib/python3.12/site-packages/bokeh/io/saving.py:98, in save(obj, filename, resources, title, template, state)
#      95 theme = state.document.theme
#      97 filename, resources, title = _get_save_args(state, filename, resources, title)
# ---> 98 _save_helper(obj, filename, resources, title, template, theme)
#      99 return abspath(expanduser(filename))
#
# File ~/.python/current/lib/python3.12/site-packages/bokeh/io/saving.py:166, in _save_helper(obj, filename, resources, title, template, theme)
#     163 from ..embed import file_html
#     164 html = file_html(obj, resources=resources, title=title, template=template or FILE, theme=theme)
# --> 166 with open(filename, mode="w", encoding="utf-8") as f:
#     167     f.write(html)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'reports_backtesting/backtesting_regression.html'
